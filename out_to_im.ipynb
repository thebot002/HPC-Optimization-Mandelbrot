# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('out.csv', sep=',', header=None)
im_array = df.values
max_val = np.max(im_array)
norm_im_array = im_array/max_val
plt.imshow(im_array)

# %%
plt.figure()
plt.imshow(np.where(im_array<1,1,0), cmap="binary")
plt.savefig('image.jpg')
